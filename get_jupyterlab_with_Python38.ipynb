# %%
#mount Google Drive, set environment variables for Prodigy and ngrok
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
import os
os.chdir("/content/drive/My Drive/prodigy_colab")
PATH = os.environ["PATH"]
# Out:
# Mounted at /content/drive

# %%
#install Anaconda3
# !wget -qO ac.sh https://repo.anaconda.com/archive/Anaconda3-2020.07-Linux-x86_64.sh 
# !bash ./ac.sh -b
# !pip install pyngrok -q
# !pip install jsonlines
# Out:
# PREFIX=/root/anaconda3
# Unpacking payload ...
# done
# done
#
# ## Package Plan ##
#
#   environment location: /root/anaconda3
#
#   added / updated specs:
#     - _ipyw_jlab_nb_ext_conf==0.1.0=py38_0
#     - _libgcc_mutex==0.1=main
#     - alabaster==0.7.12=py_0
#     - anaconda-client==1.7.2=py38_0
#     - anaconda-navigator==1.9.12=py38_0
#     - anaconda-project==0.8.4=py_0
#     - anaconda==2020.07=py38_0
#     - argh==0.26.2=py38_0
#     - asn1crypto==1.3.0=py38_0
#     - astroid==2.4.2=py38_0
#     - astropy==4.0.1.post1=py38h7b6447c_1
#     - atomicwrites==1.4.0=py_0
#     - attrs==19.3.0=py_0
#     - autopep8==1.5.3=py_0
#     - babel==2.8.0=py_0
#     - backcall==0.2.0=py_0
#     - backports.functools_lru_cache==1.6.1=py_0
#     - backports.shutil_get_terminal_size==1.0.0=py38_2
#     - backports.tempfile==1.0=py_1
#     - backports.weakref==1.0.post1=py_1
#     - backports==1.0=py_2
#     - beautifulsoup4==4.9.1=py38_0
#     - bitarray==1.4.0=py38h7b6447c_0
# ...

# %%
#a fake google.colab library
# !ln -s /usr/local/lib/python3.6/dist-packages/google \
       /root/anaconda3/lib/python3.8/site-packages/google

# %%
#install the needed packages
# !/root/anaconda3/bin/pip3 install git+https://github.com/JustAnotherArchivist/snscrape.git
# Out:
# ...
#   Cloning https://github.com/JustAnotherArchivist/snscrape.git to /tmp/pip-req-build-5d0sr_j_
#   Running command git clone -q https://github.com/JustAnotherArchivist/snscrape.git /tmp/pip-req-build-5d0sr_j_
# ...
#   Created wheel for snscrape: filename=snscrape-0.3.5.dev59+gffd9289-py3-none-any.whl size=46679 sha256=d4aa93b71101171a91fb71d0224baf1b71baf5c85dcc016a939781183161f8b9
#   Stored in directory: /tmp/pip-ephem-wheel-cache-tdredmj2/wheels/92/42/87/33fa9b18f7a75d02643a9ca3743339aec9be28c6796267c7d8
# Successfully built snscrape
# ...

# %%
#update snscrape
# !/root/anaconda3/bin/pip3 install --upgrade git+https://github.com/JustAnotherArchivist/snscrape@master
# Out:
# ...
#   Cloning https://github.com/JustAnotherArchivist/snscrape (to revision master) to /tmp/pip-req-build-2gduda1u
#   Running command git clone -q https://github.com/JustAnotherArchivist/snscrape /tmp/pip-req-build-2gduda1u
# ...
#   Created wheel for snscrape: filename=snscrape-0.3.5.dev59+gffd9289-py3-none-any.whl size=46679 sha256=965b1bbdcaab293b084c5d8e4d42a24bf57cb76d5011b4ea79650d8285bcad98
#   Stored in directory: /tmp/pip-ephem-wheel-cache-c2nb0ft2/wheels/b2/ec/a7/54feb09ffc35b481a3edc48ecf4d1fddcc6e13f36bdfda2b3b
# Successfully built snscrape
# ...
#   Attempting uninstall: snscrape
#     Found existing installation: snscrape 0.3.5.dev59+gffd9289
#     Uninstalling snscrape-0.3.5.dev59+gffd9289:
#       Successfully uninstalled snscrape-0.3.5.dev59+gffd9289
# ...

# %%
### LAUNCH JUPYTER NOTEBOOK ###

# %%
# !wget https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# !unzip ngrok-stable-linux-amd64.zip
# !./ngrok authtoken 1iDhXT06obBbCDDXUToqaxBogW6_5pWD133iU5e5cwxHHmxcW
# Out:
# --2020-10-14 08:22:07--  https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# Resolving bin.equinox.io (bin.equinox.io)... 3.230.38.119, 34.196.173.40, 54.221.249.251, ...
# Connecting to bin.equinox.io (bin.equinox.io)|3.230.38.119|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13773305 (13M) [application/octet-stream]
# Saving to: ‘ngrok-stable-linux-amd64.zip.7’
#
# ngrok-stable-linux- 100%[===================>]  13.13M  12.7MB/s    in 1.0s
#
# 2020-10-14 08:22:08 (12.7 MB/s) - ‘ngrok-stable-linux-amd64.zip.7’ saved [13773305/13773305]
#
# Archive:  ngrok-stable-linux-amd64.zip
# replace ngrok? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: ngrok
# Authtoken saved to configuration file: /root/.ngrok2/ngrok.yml

# %%
#start jupyterlab, which now has Python3 = 3.8
! nohup /root/anaconda3/bin/jupyter-lab --ip=0.0.0.0&
# Out:
# nohup: appending output to 'nohup.out'

# %%
#access through ngrok, click the link (restart session if tunnels already running)
from pyngrok import ngrok
print(ngrok.connect(8888))
# Out:
# http://d8ba4c962d81.ngrok.io
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: DeprecationWarning: Support for "return_ngrok_tunnel" as "False" is deprecated and will be removed in 5.0.0, when this method will return a NgrokTunnel instead of a str
#   This is separate from the ipykernel package so we can avoid doing imports until
